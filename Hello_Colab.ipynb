# %% [markdown]
# <a href="https://colab.research.google.com/github/ww81312/hello-colab/blob/main/Hello_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('HI~~~~~~~~~~')
# Out:
# HI~~~~~~~~~~

# %%
print('WTF')
# Out:
# WTF
